# %% [markdown]
# <a href="https://colab.research.google.com/github/OVP2023/PYstaticsForAnalize_v2/blob/main/%D0%9F%D1%83%D1%82%D1%8C_%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D1%82%D0%B8%D0%BA%D0%B0_%D0%B8%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D0%BE%D0%B5_%D0%B7%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Теперь решим задачу для агрегатора такси. Перед вами стоит важная задача: самостоятельно провести исследование данных, проверить гипотезу о поведенческом предпочтении пользователей определённого класса такси и сделать выводы, чтобы помочь компании стать лучшей на рынке. Успехов!
#
#     Используйте датасет FPS_hw_x_df_x_taxi.xlsx.
#     Исследуйте данные и постройте графики плотности распределения дистанций поездок для классов Economy и Comfort.
#     Проверьте гипотезу: «На дальние поездки пользователи предпочитают Economy-классу более комфортные условия поездки в Comfort-классе.
#     Сделайте выводы по результатам проверки. Для определения предпочтений понадобится изучение описательных статистик и графиков по классам.
#
# Примечание: гипотезы всегда формулируются однозначно, поскольку не уточняется конкретное значение дистанций, а просто сказано “дальние” и нет уточнений по статусу поездки, необходимо исследовать общее распределение.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_excel('FPS_hw_x_df_x_taxi.xlsx')
df.head()
# Out:
#    order_gk  weekday_key   hour_key  distance_km offer_class_group  \
# 0       412            7  22.967881    53.113626           Premium
# 1       436            3  19.439948     5.781342          Delivery
# 2      1327            6  19.816643    16.200071          Delivery
# 3      2013            2  19.123837    13.731643          Delivery
# 4      2241            6  23.164958    20.436380           Premium
#
#    driver_response
# 0                1
# 1                1
# 2                0
# 3                0
# 4                1

# %%
df.describe()
# Out:
#             order_gk  weekday_key     hour_key  distance_km  driver_response
# count    2000.000000  2000.000000  2000.000000  2000.000000      2000.000000
# mean   462807.384000     4.044000    21.520472    26.275849         0.587000
# std    270556.211847     2.007256     4.355491    18.876337         0.492496
# min       412.000000     1.000000    14.899553     0.024259         0.000000
# 25%    227126.500000     2.000000    18.466897    12.176830         0.000000
# 50%    458637.000000     4.000000    20.414741    22.828544         1.000000
# 75%    709420.250000     6.000000    23.497139    36.434558         1.000000
# max    919196.000000     7.000000    50.206056   138.950082         1.000000

# %%
df_1=df[df['offer_class_group']=='Economy']
df_1.head()
# Out:
#     order_gk  weekday_key   hour_key  distance_km offer_class_group  \
# 11      3845            3  21.305555    83.829973           Economy
# 13      4957            3  26.919090    14.238745           Economy
# 14      5150            5  21.139232     4.334163           Economy
# 20      8758            4  28.710615    26.412942           Economy
# 21      8985            3  18.988811    21.296147           Economy
#
#     driver_response
# 11                0
# 13                1
# 14                0
# 20                1
# 21                1

# %%
df_1.describe()
# Out:
#            order_gk  weekday_key    hour_key  distance_km  driver_response
# count     500.00000   500.000000  500.000000   500.000000       500.000000
# mean   463448.91200     3.896000   22.165311    26.283117         0.422000
# std    274029.66119     1.989246    4.063839    17.016153         0.494373
# min      3845.00000     1.000000   14.899553     0.089947         0.000000
# 25%    226962.50000     2.000000   19.006174    13.372229         0.000000
# 50%    455884.50000     4.000000   21.257715    23.798183         0.000000
# 75%    721415.75000     6.000000   24.402652    36.845287         1.000000
# max    919196.00000     7.000000   39.185553    90.516618         1.000000

# %%
df_2=df[df['offer_class_group']=='Comfort']
df_2.head()
# Out:
#     order_gk  weekday_key   hour_key  distance_km offer_class_group  \
# 6       2710            4  23.825352     2.142234           Comfort
# 15      6635            7  35.440650    10.889072           Comfort
# 16      7277            4  23.507660    28.825347           Comfort
# 17      7351            4  17.119628    17.280840           Comfort
# 23      9088            1  18.784024     4.125871           Comfort
#
#     driver_response
# 6                 1
# 15                1
# 16                1
# 17                0
# 23                0

# %%
df_2.describe()
# Out:
#             order_gk  weekday_key    hour_key  distance_km  driver_response
# count     500.000000   500.000000  500.000000   500.000000       500.000000
# mean   465289.002000     4.106000   22.943699    29.758910         0.486000
# std    272443.226582     1.968378    4.842951    17.644643         0.500305
# min      2710.000000     1.000000   15.496198     0.024259         0.000000
# 25%    232141.250000     2.000000   19.430402    16.345205         0.000000
# 50%    475479.000000     4.000000   21.704980    28.078273         0.000000
# 75%    697329.750000     6.000000   25.120825    41.300650         1.000000
# max    918656.000000     7.000000   50.206056    81.507022         1.000000

# %%
sns.distplot(df_1['distance_km'],50)
sns.distplot(df_2['distance_km'],50)
plt.title('Плотность распределения дистанций для поездок')
plt.legend(['Economy','Comfort'])
plt.show
# Out:
# <ipython-input-9-03864bc3f0e0>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1['distance_km'],50)
# <ipython-input-9-03864bc3f0e0>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_2['distance_km'],50)
# ...

# %%
from scipy.stats import ttest_ind
alpha=0.005

# %%
result=ttest_ind(df_1['distance_km'],df_2['distance_km'])
print('p-value:%.8f'%result.pvalue)
if(result.pvalue<alpha):
  print('отвергаем нулевую гипотезу')
else:
  print('не отвергаем нулевую гипотезу')
# Out:
# p-value:0.00156751
# отвергаем нулевую гипотезу

# %% [markdown]
# Благодарю за ваши замечания, доработал:
#
#     1. Сравнивал одинаковые по количеству выборки для Economy и Comfort для “общего спроса” (count=500)
#     2. Распределение данных - логнормальное распределение
#     3. В результате проверки нулевой гипотезы по критерию Стьюдента она была отвергнута, что подтверждает гипотезу, что “пользователи предпочитают Economy-классу более комфортные условия поездки в Comfort-классе”, в том числе и на дальние поездки.
